# %%
import os, requests, yaml, json
from mimetypes import guess_type
from concurrent.futures import ThreadPoolExecutor

SAMPLE_DIR = './samples_floor'
ENDPOINT_URL = 'https://ty5whne207.execute-api.us-east-1.amazonaws.com/dev/Benefits-AI-ID-Extract-Handler'
BENCHMARK_YAML_PATH = 'benchmark_floor.yaml'
TEST_YAML_PATH = 'test_floor.yaml'

# %%
def process_image(image_file):
    image_path = os.path.join(SAMPLE_DIR, image_file)
    content_type, _ = guess_type(image_path)
    content_type = content_type or 'application/octet-stream'  # Default MIME type if unknown
    # Prepare and send the file
    with open(image_path, 'rb') as image_file:
        image_data = image_file.read()
        headers = {'Content-Type': 'image/jpeg'}  # Adjust the content type based on your image format
        response = requests.post(ENDPOINT_URL, data=image_data, headers=headers)
        return os.path.basename(image_path).split(".")[0], response.text

# %%
files = os.listdir(SAMPLE_DIR)
image_files = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

results_dict = {}
with ThreadPoolExecutor(max_workers=12) as executor:
    results = executor.map(process_image, image_files)
    results_dict = dict(results)

print(results_dict)
# Out:
# {'112': '{"ADDITIONAL_INFORMATION": {}, "ID_TYPE": "", "FIRST_NAME": "FIRST", "MIDDLE_NAME": "M", "LAST_NAME": "LAST", "DATE_OF_BIRTH": "", "ADDRESS": "1100 314", "ORGANIZATION": "cca commonwealth care alliance cca commonwealth care", "ZIP_CODE_IN_ADDRESS": ""}', '15': '{"ADDITIONAL_INFORMATION": {"MIDDLE_NAME": "CHAMONTS", "SUFFIX": "", "CITY_IN_ADDRESS": "SAN DEGOCA", "STATE_IN_ADDRESS": "", "STATE_NAME": "MEXICO", "DOCUMENT_NUMBER": "91912", "EXPIRATION_DATE": "09 MAR 2019", "DATE_OF_ISSUE": "09 MAR 2019", "ENDORSEMENTS": "", "VETERAN": "", "RESTRICTIONS": "", "CLASS": "", "COUNTY": "", "PLACE_OF_BIRTH": "", "MRZ_CODE": ""}, "FIRST_NAME": "SAMANTHA", "LAST_NAME": "", "ZIP_CODE_IN_ADDRESS": "91912", "DATE_OF_BIRTH": "", "ID_TYPE": "DRIVER LICENSE FRONT", "ADDRESS": ""}', '23': '{"ADDITIONAL_INFORMATION": {"MIDDLE_NAME": "", "SUFFIX": "", "CITY_IN_ADDRESS": "ANYTOWN", "STATE_IN_ADDRESS": "NY", "STATE_NAME": "NEVADA", "DOCUMENT_NUMBER": "123456789123", "EXPIRATION_DATE": "07/01/2014", "DATE_OF_ISSUE": "07/01/2009", "ENDORSEMENTS": "", "VETERAN": "", "RESTRICTIONS": "A 4000 SO", "CLASS": "A", "COUNTY": "", "PLACE_OF_BIRTH": "", "MRZ_CODE": ""}, "FIRST_NAME": "JELANI", "LAST_NAME": "SAMPLE", "ZIP_CODE_IN_ADDRESS": "1234500000", "DATE_OF_BIRTH": "07/01/1957", "ID_TYPE": "DRIVER LICENSE FRONT", "ADDRESS": ""}', '59': '{"ADDITIONAL_INFORMATION": {}, "ID_TYPE": "SUNDESRIPUBLIK DEUTSCHLAND", "FIRST_NAME": "EXPEPRES", "MIDDLE_NAME": "COTKOOTAT", "LAST_NAME": "STROT", "DATE_OF_BIRTH": "34.02.2007", "ADDRESS": "IMPORTANT LEGAL NOTICE The information 23 this MIS", "ORGANIZATION": "", "ZIP_CODE_IN_ADDRESS": ""}', '123': '{"ADDITIONAL_INFORMATION": {}, "ID_TYPE": "Health Partners ID", "FIRST_NAME": "JANE", "MIDDLE_NAME": "A", "LAST_NAME": "DDE", "DATE_OF_BIRTH": "January", "ADDRESS": "Care Type HealthPartners Care", "ORGANIZATION": "Health Partners", "ZIP_CODE_IN_ADDRESS": "HMN07"}', '24': '{"ADDITIONAL_INFORMATION": {"MIDDLE_NAME": "", "SUFFIX": "", "CITY_IN_ADDRESS": "OKLAHOMA CITY", "STATE_IN_ADDRESS": "OK", "STATE_NAME": "OKLAHOMA", "DOCUMENT_NUMBER": "A123456789", "EXPIRATION_DATE": "01/12/2022", "DATE_OF_ISSUE": "03/19/2018", "ENDORSEMENTS": "NONE", "VETERAN": "", "RESTRICTIONS": "NONE", "CLASS": "D", "COUNTY": "", "PLACE_OF_BIRTH": "", "MRZ_CODE": ""}, "FIRST_NAME": "NICK", "LAST_NAME": "SAMPLE", "ZIP_CODE_IN_ADDRESS": "731021234", "DATE_OF_BIRTH": "01/12/1967", "ID_TYPE": "DRIVER LICENSE FRONT", "ADDRESS": "123 STATE ST."}', '37': '{"ADDITIONAL_INFORMATION": {"MIDDLE_NAME": "", "SUFFIX": "", "CITY_IN_ADDRESS": "MOBILE", "STATE_IN_ADDRESS": "AL", "STATE_NAME": "ALABAMA", "DOCUMENT_NUMBER": "12345678", "EXPIRATION_DATE": "09-04-2022", "DATE_OF_ISSUE": "09-04-2018", "ENDORSEMENTS": "", "VETERAN": "", "RESTRICTIONS": "AII", "CLASS": "D", "COUNTY": "", "PLACE_OF_BIRTH": "", "MRZ_CODE": ""}, "FIRST_NAME": "HEIDI", "LAST_NAME": "SAMPLE", "ZIP_CODE_IN_ADDRESS": "366085658", "DATE_OF_BIRTH": "05-05-1984", "ID_TYPE": "DRIVER LICENSE FRONT", "ADDRESS": "1234 SAMPLE STREET"}', '69': '{"ADDITIONAL_INFORMATION": {}, "ID_TYPE": "ACORTA FLORES FEDERACO ROSA CITIALS MERICARN", "FIRST_NAME": "ACORTA", "MIDDLE_NAME": "", "LAST_NAME": "FLORES FEDERACO ROSA CITIALS MERICARN", "DATE_OF_BIRTH": "09-19-1984", "ADDRESS": "MEXICANOS PLX MERNANDEZ ACORTA AMOUNT PERTERAL", "ORGANIZATION": "", "ZIP_CODE_IN_ADDRESS": "844481"}', '1': '{"ADDITIONAL_INFORMATION": {"MIDDLE_NAME": "", "SUFFIX": "", "CITY_IN_ADDRESS": "NONTREAL", "STATE_IN_ADDRESS": "PR", "STATE_NAME": "", "DOCUMENT_NUMBER": "", "EXPIRATION_DATE": "2023-03-30", "DATE_OF_ISSUE": "", "ENDORSEMENTS": "NONE", "VETERAN": "", "RESTRICTIONS": "NONE", "CLASS": "5", "COUNTY": "", "PLACE_OF_BIRTH": "NONTREAL", "MRZ_CODE": ""}, "FIRST_NAME": "THOR", "LAST_NAME": "ODINSON", "ZIP_CODE_IN_ADDRESS": "", "DATE_OF_BIRTH": "", "ID_TYPE": "DRIVER LICENSE FRONT", "ADDRESS": "69 RUE BIG HAMMER"}', '12': '{"ADDITIONAL_INFORMATION": {"MIDDLE_NAME": "DOE", "SUFFIX": "", "CITY_IN_ADDRESS": "JEFFERSON CITY", "STATE_IN_ADDRES ...

# %%
# Function to convert JSON to YAML
def convert_json_to_yaml(result_dict: dict):
    dict_int_keys = {int(k): result_dict[k] for k in result_dict}
    sorted_dict = {k: dict_int_keys[k] for k in sorted(dict_int_keys, key=int)}
    parsed_data = {}
    for key, value in sorted_dict.items():
        fields = json.loads(value)
        # Extract the required fields
        entry_dict = {}
        for field in fields:
            if field != 'ADDITIONAL_INFORMATION':
                entry_dict[field] = fields.get(field)
        parsed_data[key] = entry_dict
    # Convert dictionary to YAML string
    yaml_data = yaml.dump(parsed_data, default_flow_style=False)
    return yaml_data
# Convert JSON to YAML
yaml_result = convert_json_to_yaml(results_dict)
# Optionally, write to a YAML file
with open(TEST_YAML_PATH, "w") as f:
    f.write(yaml_result)

# %%
import yaml

stats_dict = {}

def load_yaml(file_path):
    with open(file_path, 'r') as file:
        return yaml.safe_load(file)
    
def add_statistic(id_type, entry_field_count, diff_field_count):
    diff_entry_increment = 1 if diff_field_count != 0 else 0
    if id_type not in stats_dict:
        stats_dict[id_type] = (1,diff_entry_increment,entry_field_count, diff_field_count)
    else:
        total_entry_counter, diff_entry_counter, total_field_counter, diff_field_counter = stats_dict[id_type]
        stats_dict[id_type] = (total_entry_counter + 1, diff_entry_counter + diff_entry_increment, total_field_counter + entry_field_count, diff_field_counter + diff_field_count)

def compare_yaml(benchmark_path, test_path):
    benchmark_data, test_data = load_yaml(benchmark_path), load_yaml(test_path)
    if not benchmark_data:
        raise Exception('Need to populate benchmark YAML')
    for entry_name in benchmark_data:
        print(f'Now reviewing entry {entry_name}')
        if entry_name not in test_data:
            print(f'Skipped {entry_name}')
            continue
        entry_field_counter, diff_field_counter = 0, 0
        benchmark_entry, test_entry, id_type = benchmark_data[entry_name], test_data[entry_name], ''
        for field_name in benchmark_entry:
            entry_field_counter += 1
            if field_name not in test_entry:
                diff_field_counter += 1
                continue
            benchmark_field, test_field = benchmark_entry[field_name], test_entry[field_name]
            if field_name == 'ID_TYPE':
                id_type = test_field
            if benchmark_field != test_field:
                print(f'{test_field if test_field else "[EMPTY]"} should be: {benchmark_field if benchmark_field else "[EMPTY]"}')
                diff_field_counter += 1
        if not id_type:
            add_statistic('Misc', entry_field_counter, diff_field_counter)
            continue
        add_statistic(id_type, entry_field_counter, diff_field_counter)

# Compare the files and print the number of different entries
compare_yaml(BENCHMARK_YAML_PATH, TEST_YAML_PATH)
# Out:
# Now reviewing entry 1
# 69 RUE BIG HAMMER should be: 69 RUE BIG HAMMER MONTREAL
# [EMPTY] should be: 03/30/1996
# Now reviewing entry 2
# [EMPTY] should be: 6989 SUMMERSIDE BLVD PORTLAND ME 04101
# 02/14/1974 should be: 02/17/1981
# [EMPTY] should be: JULIE
# [EMPTY] should be: SUMMERS
# Now reviewing entry 3
# 123 MAIN STREET should be: 123 MAIN STREET INDIANAPOLIS IN 46204-0000
# Now reviewing entry 4
# 123 YOUR ST should be: 123 YOUR ST SIOUX FALLS SD 57105
# Now reviewing entry 5
# 1234 MAIN STREET RD should be: 1234 MAIN STREET RD RIVERDALE GA 30274
# Now reviewing entry 6
# 123 MAIN STREET should be: 123 MAIN STREET ANYTOWN GA 39999
# Now reviewing entry 7
# [EMPTY] should be: ADDRESS LINE 1 BOISE IO
# [EMPTY] should be: FIRSTNAME
# [EMPTY] should be: LASTNAME
# Now reviewing entry 8
# [EMPTY] should be: 123 ANY STREET GLEN BURNIE MD 21062
# SAMPLE should be: JANE
# [EMPTY] should be: SAMPLE
# Now reviewing entry 9
# 1284 WHITTY DR should be: 1284 WHITTY DR SLIDELL LA
# Now reviewing entry 10
# [EMPTY] should be: 312 15TH STREET DUNBAR WV 25064
# [EMPTY] should be: ANOTHER
# [EMPTY] should be: SAMPLE
# Now reviewing entry 11
# 910 GOVERNMENT STREET should be: 910 GOVERNMENT STREET VICTORIA BC V8W 3Y8
# 04-06-1987 should be: 1987-APR-06
# CAN should be: SAMPLE
# DRIVER'S LICENCE and SERVICES CARD should be: DRIVER LICENSE BACK
# SAMPLE should be: TEST CARD
# Now reviewing entry 12
# [EMPTY] should be: 123 SAMPLE STREET APT.4 JEFFERSON CITY MO 65109
# Now reviewing entry 13
# 12 PATTERSON ROAD should be: 12 PATTERSON ROAD OKLAHOMA CITY OK 78160-0000
# Now reviewing entry 14
# 123 STREET LINE 2 should be: 123 STREET ADDRESS ADDRESS LINE 2 MONTPELIER VT 12345-1234
# Now reviewing entry 15
# [EMPTY] should be: 690 S CLEARWATER LN SAN DIEGO CA USA 91913
# [EMPTY] should be: 09 MAR 2014
# [EMPTY] should be: DHUMONTS
# Now reviewing entry 16
# 123 MAIN STREET should be: 123 MAIN STREET ANYTOWN ND 12345
# Now reviewing entry 17
# 1234 YOUR STREET should be: 1234 YOUR STREET WEST VALLEY CITY UT 84130
# Now reviewing entry 18
# 100 MAIN STREET APT. 1 should be: 100 MAIN STREET APT. 1 FRANKFORT KY 40601-0000
# Now reviewing entry 19
# 1234 YOUR STREET should be: 1234 YOUR STREET WATERLOO IA 50702
# Now reviewing entry 20
# LEAMLY should be: ALEXANDER
# Now reviewing entry 21
# [EMPTY] should be: 123 ANYWHERE ST ANYTOWN OH 12345
# [EMPTY] should be: DOE
# Now reviewing entry 22
# 5700 SOUTHPOINT CENTRE should be: 5700 SOUTHPOINT CENTRE BLVD FREDERICKSBURG VA 22407
# [EMPTY] should be: 01/19/2007
# JUJANA should be: JULIANA
# Now reviewing entry 23
# [EMPTY] should be: 123 SAMPLE DRIVE APT 12 ANYTOWN NY 12345-0000
# Now reviewing entry 24
# 123 STATE ST. should be: 123 STATE ST. OKLAHOMA CITY OK 73102-1234
# Now reviewing entry 25
# [EMPTY] should be: 600 NEW LONDON AVE CRANSTOWN RI
# [EMPTY] should be: IAM
# Now reviewing entry 26
# 1100 NEW BERN AVE should be: 1100 NEW BERN AVE RALEIGH NC 27697-0001
# Now reviewing entry 27
# 123 MAIN ST should be: 123 MAIN ST JACKSON MS 39216-1234
# Now reviewing entry 28
# 123 STATE STREET should be: 123 STATE STREET ALBUQUERQUE NM 87102
# Now reviewing entry 29
# 1906 LANA AVE NE should be: 1906 LANA AVE NE SALEM  OR 97314
# Now reviewing entry 30
# 123 NORTH STREET APT. should be: 123 NORTH STREET APT. 2 TOPEKA KS 68612-1234
# Now reviewing entry 31
# 4802 SHEBOYGAN AVE should be: 4802 SHEBOYGAN AVE MADISON WI 53705
# Now reviewing entry 32
# 123 MAIN STREET should be: 123 MAIN STREET ANYTOWN NE 12345
# Now reviewing entry 33
# 123 STREET LINE 2 should be: 123 STREET LINE 2 MONTPELIER VT 12345-1234
# Now reviewing entry 34
# 123 ANY STREET should be: 123 ANY STREET GLEN BURNIE MD 21052
# [EMPTY] should be: JANE
# [EMPTY] should be: SAMPLE
# Now reviewing entry 35
# 2900 APALACHEE PKWY should be: 2900 APALACHEE PKWY TALLAHASSEE FL 32399
# Now reviewing entry 36
# 3456 SOMEWHERE AVE should be: 3456 SOMEWHERE AVE TALLAHASSEE FL 32399
# Now reviewing entry 37
# 1234 SAMPLE STREET should be: 1234 SAMPLE STREET MOBILE AL 36608-5658
# Now reviewing entry 38
# ausures should be: [EMPTY]
# COLORADO DRIVER LICENSE should be: DRIVER LICENSE FRONT
# Now reviewing entry 39
# 200 SOUTH MAIN STREET should be: 200 SOUTH MAIN STREET SALT LAKE CITY UT 84115
# Now reviewing entry 40
# 123 MAIN STREET should be: 123 MAIN STREET HELENA MT 59601
# Now reviewing entry 41
# Now reviewing entry 42
# Now reviewing entry 43
# Now reviewing entry 44
# Now reviewing entry 45
# [EMPTY] should be: LAST NAME
# Now reviewing entry 46
# Now reviewing entry 47
# - should be: [EMPTY]
# Now reviewing entry 48
# Now reviewing entry 49
# Now reviewing entry 50
# Now reviewing entry 51
# 00-templ-com should be: [EMPTY]
# Ps should be: [EMPTY]
# LICA of ANGOLA should be: [EMPTY]
# gotempl.cc cc EXTEMPL.COM : to templ.com tempt.com should be: [EMPTY]
# Now reviewing entry 52
# Now reviewing entry 53
# [EMPTY] should be: CITIZEN
# Now reviewing entry 54
# 00.08.2013 should be: [EMPTY]
# PC ADE K11000944 HISEYHU should be: PASSPORT
# Now reviewing entry 55
# Now reviewing entry 56
# Now reviewing entry 57
# Now reviewing entry 58
# Now reviewing entry 59
# IMPORTANT LEGAL NOTICE The information 23 this MIS should be: STROT IMPORTANT LEGAL NOTICE The information 23 this MIS
# 34.02.2007 should be: [EMPTY]
# STROT should be: COTKOOTAT
# Now reviewing entry 60
# Republic of Ghana - - GHA H0000014 should be: [EMPTY]
# Not available should be: [EMPTY]
# SPOCIMEN should be: [EMPTY]
# Passport should be: [EMPTY]
# MALE should be: [EMPTY]
# Now reviewing entry 61
# Now reviewing entry 62
# Now reviewing entry 63
# Now reviewing entry 64
# Now reviewing entry 65
# Now reviewing entry 66
# Now reviewing entry 67
# [EMPTY] should be: 11.03.1990
# Now reviewing entry 68
# 11-19-1990 should be: 11.03.1990
# LIETUVOS RESPUBLIKA should be: PASSPORT
# Now reviewing entry 69
# MEXICANOS PLX MERNANDEZ ACORTA AMOUNT PERTERAL should be: PLX MERNANDEZ ACORTA AMOUNT PERTERAL
# 09-19-1984 should be: 19.07.2014
# ACORTA should be: FEDERACO ROSA
# ACORTA FLORES FEDERACO ROSA CITIALS MERICARN should be: MEXICANOS
# FLORES FEDERACO ROSA CITIALS MERICARN should be: CITIALS MERICARN
# Now reviewing entry 70
# [EMPTY] should be: 09/29/1955
# Now reviewing entry 71
# Now reviewing entry 72
# Now reviewing entry 73
# Now reviewing entry 74
# Now reviewing entry 75
# Now reviewing entry 76
# [EMPTY] should be: 123 STREET ADDRESS
# Now reviewing entry 77
# Now reviewing entry 78
# Now reviewing entry 80
# Now reviewing entry 81
# Andracco should be: Signature
# [EMPTY] should be: MAX - 2013 - TANK
# Max should be: NATION
# Republica - / Nation Print - - . - Max - 2013 - Tank Signature Andracco should be: REPUBLICA
# Tank should be: PRINT
# Now reviewing entry 82
# Now reviewing entry 83
# gb should be: [EMPTY]
# gb should be: [EMPTY]
# gb should be: [EMPTY]
# gb should be: [EMPTY]
# Now reviewing entry 84
# 27.164.2014 MANILA should be: [EMPTY]
# 03-16-1980 should be: 16 MAR 1980
# MARIA should be: MARSA
# Passport should be: [EMPTY]
# DELA CRUZ should be: CRUZ
# Now reviewing entry 85
# GARCAO should be: GARCAO DE MAGALHAES
# Now reviewing entry 86
# The / of Parents which of the Account of - married - - and of - - - way - in am PROPERTY TO - - PR - ORN --- - --- - are - - 2007 US - *********** POCTABLE t should be: The way in am PROPERTY TO
# [EMPTY] should be: 2K250916
# [EMPTY] should be: SCHAIRS
# [EMPTY] should be: US
# SCHAIRS should be: POCTABLE
# Now reviewing entry 87
# Now reviewing entry 88
# ZEE ZEE ZEE should be: LINDA NE ZEE ZEE
# Now reviewing entry 89
# [EMPTY] should be: VZOR
# Now reviewing entry 90
# Now reviewing entry 91
# SHADYA should be: SHADYA MUSA
# Now reviewing entry 92
# [EMPTY] should be: Unknown
# [EMPTY] should be: Unknown
# Now reviewing entry 93
# Now reviewing entry 94
# [EMPTY] should be: TKACHENKO
# Now reviewing entry 95
# Now reviewing entry 96
# [EMPTY] should be: 000000-00-0
# ZAMBE PASSPORT should be: PASSPORT
# 200 2N000000 000000-00-0 should be: 200 2N000000
# Now reviewing entry 97
# V veriheal MEDICAL PATIENT to . 123,456 789 should be: [EMPTY]
# 01-01-2000 should be: JAN 01 2000
# Dan should be: DAN
# Medical Patient ID should be: [EMPTY]
# [EMPTY] should be: K
# Now reviewing entry 98
# UnitedHealthcare r L LIMG Options.PPC Health Plan (80840) 9118772604 Member ID: Network Effective Date Group Number Payer D 87726 should be: [EMPTY]
# [EMPTY] should be: Unknown
# Membership ID should be: Member ID
# Points of Care should be: Points of Care Insured
# Now reviewing entry 99
# COPHP Universal Benefits, Inc. CIPHP 500 Patroon Creek Blvd. Albany, NY 12206-1057 should be: [EMPTY]
# MM-DD-YYYY should be: DOE
# Now reviewing entry 100
# HIGH and Substance Use tarrington MO 03560 should be: [EMPTY]
# 01-08-2000 should be: 01/08/2000
# SMETH should be: Tanicas
# [EMPTY] should be: Member
# OF should be: Smeth
# Now reviewing entry 101
# Plan: Subscriber Name: Subscriber ID Provider Provider Phone Provider Group should be: Moins Healthcare butter Rx PCN Rx Group
# Molina should be: MOLINA
# TDI MOLINA ID # should be: MOLINA ID
# Marketplace should be: HEALTHCARE Member
# Now reviewing entry 102
# [EMPTY] should be: UNGA SMITH INVOICE SAMPLE
# [EMPTY] should be: 123456
# [EMPTY] should be: HMD
# Membership ID should be: Member ID
# SMITH should be: Gree
# Now reviewing entry 103
# children's ISSUER: 80840 MEDICAL CENTER should be: [EMPTY]
# MM-DD-YYYY should be: [EMPTY]
# PROOF should be: Q PROOF
# Now reviewing entry 104
# MidlandsChoice Administered By Cigna Health and Life Insurance Co Open Access Plus Coverage Effective Date GLAL/2022 No Referral Required accordance should be: [EMPTY]
# 12-29-1989 should be: [EMPTY]
# ID should be: myCIGNA ID
# Now reviewing entry 105
# DRIVER LICENSE FRONT should be: CIGNA ID
# Now reviewing entry 106
# [EMPTY] should be: MVP HEALTHCARE
# SAMPLE should be: Q SAMPLE
# Now reviewing entry 107
# [EMPTY] should be: Address not provided
# [EMPTY] should be: Date not provided
# [EMPTY] should be: EMBLEM HEALTH ID
# Now reviewing entry 108
# Not provided should be: [EMPTY]
# Not provided should be: [EMPTY]
# SAMPLE should be: [EMPTY]
# EmblemHealth Plan should be: EmblemHealth Plan Name
# MEMBER should be: No Referral Required
# Now reviewing entry 109
# YXY should be: SAMPLE
# SAMPLE MEMBER should be: YXY
# FAM should be: MEMBER
# Now reviewing entry 110
# [EMPTY] should be: Not provided
# [EMPTY] should be: Not provided
# [EMPTY] should be: Health Insurance Plan
# Now reviewing entry 111
# Now reviewing entry 112
# 1100 314 should be: [EMPTY]
# FIRST should be: <FIRST>
# [EMPTY] should be: MedicareR Member
# LAST should be: M LAST
# Now reviewing entry 113
# 500 Patroon Creek Blvd. should be: [EMPTY]
# xx/xx/xxxx should be: [EMPTY]
# CIPHP should be: COPHP Universal Benefits* Inc. CIPHP
# Now reviewing entry 114
# DETRORE Local 1 should be: [EMPTY]
# 06-20-2021 should be: [EMPTY]
# Local should be: [EMPTY]
# Carefirst 00 should be: DRIVER LICENSE BACK
# Member Name PRODUCT NAME) 2 First Name Last Name) FOROUP - Member ID PCP NAME - ###### LAST NAME FIRST NAME) Group #### 3 (* should be: [EMPTY]
# Now reviewing entry 115
# Not Available should be: [EMPTY]
# Not Available should be: [EMPTY]
# Not Available should be: OMNI BLUE HEALTHCARE ID
# Now reviewing entry 116
# N/A should be: [EMPTY]
# N/A should be: [EMPTY]
# N/A should be: HarvardPilgrim HealthCare PLAN
# Now reviewing entry 117
# Not provided should be: [EMPTY]
# Not provided should be: [EMPTY]
# John should be: JOHN Q
# Membership ID should be: AARP Membership ID
# Sample should be: SAMPLE
# Now reviewing entry 118
# DRIVER LICENSE FRONT should be: BLUE CROSS BLUE SHIELD
# Now reviewing entry 119
# FIRST should be: FIRST A.
# [EMPTY] should be: TUFTS HEALTH PLAN
# Now reviewing entry 120
# Now reviewing entry 121
# Skipped 121
# Now reviewing entry 122

# %%
def report_results():
    total_entries, total_diff_entries, total_fields, total_diff_fields = 0,0,0,0
    for id_type in stats_dict:
        if id_type == 'DRIVER LICENSE FRONT' or id_type == 'PASSPORT':
            entries, diff_entries, fields, diff_fields = stats_dict[id_type]
            entries_acc, fields_acc = round(float(100-(100*diff_entries/entries)),2), round(float(100-(100*diff_fields/fields)),2)
            print(f'For {id_type}:\n\tEntries Accuracy:\t{entries_acc}%\n\tFields Accuracy:\t{fields_acc}%')
            total_entries += entries
            total_diff_entries += diff_entries
            total_fields += fields
            total_diff_fields += diff_fields
    total_entries_acc, total_fields_acc = round(float(100-(100*total_diff_entries/total_entries)),2), round(float(100-(100*total_diff_fields/total_fields)),2)
    print(f'Total:\n\tEntries Accuracy:\t{total_entries_acc}%\n\tFields Accuracy:\t{total_fields_acc}%')
report_results()
# Out:
# For DRIVER LICENSE FRONT:
# 	Entries Accuracy:	28.33%
# 	Fields Accuracy:	79.67%
# For DRIVER'S LICENCE and SERVICES CARD:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For COLORADO DRIVER LICENSE:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	60.0%
# For LICA of ANGOLA:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For PASSPORT:
# 	Entries Accuracy:	65.22%
# 	Fields Accuracy:	91.3%
# For PC ADE K11000944 HISEYHU:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	50.0%
# For SUNDESRIPUBLIK DEUTSCHLAND:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# For Passport:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For LIETUVOS RESPUBLIKA:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	50.0%
# For ACORTA FLORES FEDERACO ROSA CITIALS MERICARN:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For Republica - / Nation Print - - . - Max - 2013 - Tank Signature Andracco:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For gb:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	20.0%
# For Misc:
# 	Entries Accuracy:	10.0%
# 	Fields Accuracy:	32.0%
# For My:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	60.0%
# For ZAMBE PASSPORT:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	25.0%
# For Medical Patient ID:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For Membership ID:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	6.67%
# For HRA ID:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	60.0%
# For TDI MOLINA ID #:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	20.0%
# For CVS CAREMARK Prescription Card:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# For ID:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# For EmblemHealth Plan:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For SAMPLE MEMBER:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# For CIPHP:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# For Carefirst 00:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	0.0%
# For Not Available:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# For N/A:
# 	Entries Accuracy:	0.0%
# 	Fields Accuracy:	40.0%
# Total:
# 	Entries Accuracy:	27.5%
# 	Fields Accuracy:	64.57%
